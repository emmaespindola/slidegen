# %% [markdown]
# # SlideGen: Generador Automático de Presentaciones con IA
#
# ## 🧠 ¿Qué es este proyecto?
#
# SlideGen es un proyecto que transforma textos largos (como un informe, resumen o trabajo práctico) en una presentación de diapositivas. Utiliza inteligencia artificial (IA) para dividir el texto, crear títulos y subtítulos, generar puntos clave y, además, agregar imágenes ilustrativas.
#
# Este proyecto fue realizado para la materia *IA Generación de Prompts* y tiene como objetivo mostrar cómo podemos usar herramientas de IA para facilitar tareas cotidianas, como armar una presentación.

# %% [markdown]
# ## 🎯 Objetivos
#
# - Utilizar inteligencia artificial para generar presentaciones a partir de textos extensos.
# - Transformar información escrita en contenido visual claro, dividido por secciones.
# - Combinar dos tipos de modelos de IA:
#   - **Texto a texto** (para resumir y estructurar la información).
#   - **Texto a imagen** (para generar ilustraciones relacionadas con el contenido).
# - Crear una herramienta práctica que ayude a estudiantes o profesionales a preparar sus presentaciones de manera más rápida y creativa.

# %% [markdown]
# ## 🛑 Presentación del problema a abordar
#
# Armar presentaciones es una tarea común en trabajos prácticos, exposiciones o informes. Sin embargo, muchas personas encuentran difícil o lento transformar un texto largo en una presentación clara y visual.
#
# Este proceso suele requerir:
# - Resumir ideas principales.
# - Dividir el contenido en diapositivas.
# - Pensar títulos y subtítulos.
# - Buscar imágenes que acompañen la información.
#
# Esto puede llevar mucho tiempo, sobre todo si se quiere que la presentación sea atractiva y profesional. Por eso, surge la necesidad de una herramienta que facilite este proceso de forma rápida, automática y creativa.
#
# SlideGen busca resolver este problema usando inteligencia artificial.

# %% [markdown]
# ## 💡 Desarrollo de la propuesta de solución
#
# La solución propuesta se basa en el uso de inteligencia artificial para automatizar la creación de presentaciones a partir de un texto base.
#
# SlideGen funciona en tres pasos:
# 1. **Procesar el texto**: Se utiliza un modelo de IA de tipo texto a texto (como ChatGPT) para dividir el contenido en secciones, generar títulos, subtítulos y listas con los puntos clave de cada diapositiva.
# 2. **Generar imágenes**: Para ilustrar las diapositivas, se usan herramientas de texto a imagen (como NightCafe, Leonardo AI o similares) que generan imágenes a partir de descripciones creadas automáticamente.
# 3. **Organizar el contenido**: Todo se organiza como si fuera una presentación tipo Google Slides: una portada, varias diapositivas de contenido y un cierre o conclusión.
#
# Los prompts fueron diseñados para:
# - Detectar la estructura del texto original.
# - Dividirlo según la cantidad de diapositivas deseada.
# - Generar imágenes relacionadas con el contenido de cada sección.
#
# El resultado es una base visual de presentación, lista para ser usada o ajustada por el usuario.

# %% [markdown]
# ## ✅ Justificación de la viabilidad del proyecto
#
# Este proyecto es totalmente viable porque se puede realizar sin necesidad de programar ni instalar herramientas complicadas.
#
# Para desarrollarlo se utilizan:
# - **Google Colab**, una plataforma gratuita para trabajar online.
# - **Modelos de inteligencia artificial disponibles públicamente** como ChatGPT para generar texto, y herramientas gratuitas de generación de imágenes como NightCafe o Leonardo AI.
# - **Prompts diseñados a mano**, sin necesidad de entrenar un modelo ni usar código avanzado.
#
# Además, se puede realizar en poco tiempo, ya que:
# - Las herramientas de IA responden rápidamente.
# - Los resultados se pueden copiar y pegar directamente en la notebook.
# - No se requiere infraestructura técnica adicional.
#
# Este proyecto demuestra que una persona sin conocimientos previos en programación puede aplicar IA de forma útil y creativa.

# %% [markdown]
# ## 🧪 Metodología
#
# El desarrollo de SlideGen se realizará en varios pasos simples:
#
# 1. **Ingreso del texto base**: el usuario copia y pega un texto largo (por ejemplo, un informe, trabajo práctico o artículo).
# 2. **Generación de estructura de la presentación**:
#    - Se utiliza un modelo de IA (texto a texto) para dividir el texto en secciones.
#    - Se generan títulos, subtítulos y listas con puntos clave para cada diapositiva.
# 3. **Creación de prompts para imágenes**:
#    - Se escribe un prompt por cada sección del texto para generar imágenes ilustrativas.
#    - Se utiliza una herramienta gratuita de generación de imágenes como NightCafe o Leonardo AI.
# 4. **Insertar imágenes y contenido**:
#    - Las imágenes generadas se agregan a cada sección del proyecto.
#    - Se visualiza todo junto en la notebook, simulando cómo sería una presentación completa.
#
# Durante todo el proceso se aplican técnicas de *fast prompting* para obtener respuestas claras, ordenadas y fáciles de usar en una presentación.

# %% [markdown]
# ## 🛠️ Herramientas y tecnologías
#
# Para desarrollar SlideGen utilizo las siguientes herramientas:
#
# - **Google Colab**: Plataforma online gratuita para escribir y ejecutar código, y combinar texto, imágenes y resultados en un solo lugar.
# - **ChatGPT (modelo texto a texto)**: Para procesar el texto ingresado, generar resúmenes, títulos y puntos clave que estructuran la presentación.
# - **NightCafe / Leonardo AI (modelos texto a imagen)**: Para crear imágenes originales que acompañan cada diapositiva según la descripción generada.
# - **Fast prompting**: Técnicas para diseñar prompts claros y específicos que permitan obtener respuestas precisas y útiles en poco tiempo.
#
# Estas herramientas no requieren conocimientos técnicos avanzados ni instalaciones complicadas, y muchas ofrecen opciones gratuitas.

# %% [markdown]
# ## 💻 Implementación
#
# En esta etapa, se desarrollan los prompts que permiten transformar un texto largo en una presentación con imágenes.
#
# ### Ejemplo de prompt para texto a texto (ChatGPT):
#
# "Divide el siguiente texto en 5 diapositivas para una presentación. Para cada diapositiva, crea un título y 3 puntos clave:
#
# [PEGA AQUÍ EL TEXTO]"
#
# ### Ejemplo de prompt para texto a imagen (NightCafe o Leonardo AI):
#
# "Genera una imagen que represente [DESCRIPCIÓN DEL TEMA DE LA DIAPOSITIVA], estilo moderno y colorido."
#
# ---
#
# A continuación se muestran ejemplos de imágenes generadas con los prompts descritos, las cuales pueden insertarse en la presentación para hacerla más atractiva y visual.

# %% [markdown]
# ![Flux_Dev_Genera_una_imagen_que_represente_una_diapositiva_para_1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 📊 Resultados
#
# La implementación de SlideGen permitió:
#
# - Convertir textos largos en una estructura de presentación con títulos y puntos clave.
# - Generar imágenes relevantes para cada diapositiva usando herramientas de texto a imagen.
# - Reducir significativamente el tiempo que una persona invierte en armar una presentación atractiva y organizada.
# - Crear una presentación base que puede ser ajustada y personalizada según las necesidades del usuario.
#
# Aunque no es una solución automática completa (todavía requiere supervisión y ajuste), cumple con el objetivo de facilitar y acelerar el proceso de creación de presentaciones.
#
# En resumen, la combinación de modelos de IA y prompts diseñados adecuadamente lograron el resultado esperado.

# %% [markdown]
# ## 🏁 Conclusiones
#
# SlideGen demostró que es posible usar inteligencia artificial para transformar textos extensos en presentaciones visuales y bien estructuradas, sin necesidad de conocimientos técnicos avanzados.
#
# Los objetivos planteados se cumplieron al:
#
# - Facilitar la generación automática de títulos, puntos clave y estructura para cada diapositiva.
# - Integrar imágenes ilustrativas generadas por IA que enriquecen el contenido.
# - Brindar una herramienta práctica y accesible para estudiantes y profesionales que necesitan presentar información rápidamente.
#
# El proyecto también muestra el potencial del fast prompting para optimizar la interacción con modelos de IA y obtener resultados claros y útiles.
#
# Como mejora futura, se podría desarrollar una interfaz más amigable para que el usuario final no dependa de plataformas como Google Colab.

# %% [markdown]
# ## 📚 Referencias
#
# - OpenAI. ChatGPT. https://chat.openai.com/
# - NightCafe Studio. Generación de imágenes con IA. https://nightcafe.studio/
# - Leonardo AI. Generación de imágenes por IA. https://leonardo.ai/
# - Google Colab. Plataforma para notebooks colaborativas. https://colab.research.google.com/
# - Material del curso “IA Generación de prompts” - Universidad.
